# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
data={"color":["red","green","yellow","Voilet"]}
df=pd.DataFrame(data)
df.head()
# Out:
#     color
# 0     red
# 1   green
# 2  yellow
# 3  Voilet

# %%
label_encoder=LabelEncoder()
df["Color_label"]=label_encoder.fit_transform(df["color"])
df.head()
# Out:
#     color  Color_label
# 0     red            2
# 1   green            1
# 2  yellow            3
# 3  Voilet            0

# %%
one_hot_encoding=OneHotEncoder(sparse_output=False)
color_encoded=one_hot_encoding.fit_transform(df[['color']])
color_encoded_df=pd.DataFrame(color_encoded,columns=one_hot_encoding.get_feature_names_out(['color']))
df=pd.concat([df,color_encoded_df],axis=1)
df.head()
# Out:
#     color  Color_label  color_Voilet  color_green  color_red  color_yellow
# 0     red            2           0.0          0.0        1.0           0.0
# 1   green            1           0.0          1.0        0.0           0.0
# 2  yellow            3           0.0          0.0        0.0           1.0
# 3  Voilet            0           1.0          0.0        0.0           0.0
