# %%
k=[4,2.56789,9,87.9999,40,'hyderabad']
k
# Out:
# [4, 2.56789, 9, 87.9999, 40, 'hyderabad']

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2.56789,9,87.9999,40]
k
# Out:
# [4, 2.56789, 9, 87.9999, 40]

# %%
pd.Series(k)
# Out:
# 0     4.00000
# 1     2.56789
# 2     9.00000
# 3    87.99990
# 4    40.00000
# dtype: float64

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([47, 41, 20, 47, 42, 47, 20, 49, 28, 45, 41, 41, 21, 30, 31])

# %%
a.ndim
# Out:
# 1

# %%
s=pd.Series(a)
s
# Out:
# 0     47
# 1     41
# 2     20
# 3     47
# 4     42
# 5     47
# 6     20
# 7     49
# 8     28
# 9     45
# 10    41
# 11    41
# 12    21
# 13    30
# 14    31
# dtype: int64

# %%
s[0]
# Out:
# 47

# %%
s[4:10]
# Out:
# 4    42
# 5    47
# 6    20
# 7    49
# 8    28
# 9    45
# dtype: int64

# %%
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[171, 109, 175, 184, 182],
#        [155, 198, 104, 128, 120],
#        [184, 134, 194, 130, 124],
#        [142, 163, 121, 129, 174],
#        [154, 114, 133, 143, 135],
#        [180, 170, 150, 129, 128]])

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (6, 5)

# %%
df=pd.DataFrame(b,columns=['Roll','name','age','country','adds'],index=[182,183,185,186,187,188]
df
# Out:
#   File "<ipython-input-31-6e2a797da357>", line 1
#     df=pd.DataFrame(b,columns=['Roll','name','age','country','adds'],index=[182,183,185,186,187,188]
#                    ^
# SyntaxError: '(' was never closed

# %%
df
# Out:
#    Roll  name  age  Country  Adress
# 0   171   109  175      184     182
# 1   155   198  104      128     120
# 2   184   134  194      130     124
# 3   142   163  121      129     174
# 4   154   114  133      143     135
# 5   180   170  150      129     128

# %%
df.iloc[0,0]
# Out:
# 171

# %%
df.loc[182,'Roll']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: 182 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-86e2cf568384> in <cell line: 0>()
# ----> 1 df.loc[182,'Roll']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
# ...

# %%
df.iloc[0,0:3]
# Out:
# Roll    171
# name    109
# age     175
# Name: 0, dtype: int64

# %%
df.iloc[[0,5]]
# Out:
#    Roll  name  age  Country  Adress
# 0   171   109  175      184     182
# 5   180   170  150      129     128

# %%
df.iloc[[1,3,4]]
# Out:
#    Roll  name  age  Country  Adress
# 1   155   198  104      128     120
# 3   142   163  121      129     174
# 4   154   114  133      143     135

# %%
df
# Out:
#    Roll  name  age  Country  Adress
# 0   171   109  175      184     182
# 1   155   198  104      128     120
# 2   184   134  194      130     124
# 3   142   163  121      129     174
# 4   154   114  133      143     135
# 5   180   170  150      129     128

# %%
df.age
# Out:
# 0    175
# 1    104
# 2    194
# 3    121
# 4    133
# 5    150
# Name: age, dtype: int64

# %%
df['age']
# Out:
# 0    175
# 1    104
# 2    194
# 3    121
# 4    133
# 5    150
# Name: age, dtype: int64

# %%
df[['age','adds']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-37fa73f8385a> in <cell line: 0>()
# ----> 1 df[['age','adds']]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('planets')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (6, 5)

# %%
df.columns
# Out:
# Index(['Roll', 'name', 'age', 'Country', 'Adress'], dtype='object')
